# %% [markdown]
# # Automação de Sistemas e Processos com Python
#
# ### Desafio:
#
# Para controle de custos, todos os dias, seu chefe pede um relatório com todas as compras de mercadorias da empresa.
# O seu trabalho, como analista, é enviar um e-mail para ele, assim que começar a trabalhar, com o total gasto, a quantidade de produtos compradas e o preço médio dos produtos.
#
# E-mail do seu chefe: para o nosso exercício, coloque um e-mail seu como sendo o e-mail do seu chefe<br>
# Link de acesso ao sistema da empresa: https://pages.hashtagtreinamentos.com/aula1-intensivao-sistema
#
# Para resolver isso, vamos usar o pyautogui, uma biblioteca de automação de comandos do mouse e do teclado

# %%
import pyautogui
import time

pyautogui.PAUSE = 1
# pyautogui.click -> clicar com o mouse
# pyautogui.write -> escrever um texto
# pyautogui.press -> apertar uma tecla
# pyautogui.hotkey -> apertar uma combinação de teclas

#Passo 1: Acessar o sistema da empresa
pyautogui.hotkey("ctrl", "t")
pyautogui.write("https://pages.hashtagtreinamentos.com/aula1-intensivao-sistema")
pyautogui.hotkey("enter")
time.sleep(5)

    
#Passo 2: Fazer login no sistema
pyautogui.click(x=679, y=339)
pyautogui.write("meu login")
time.sleep(2)

pyautogui.click(x=694, y=429)
pyautogui.write("minha senha")
time.sleep(2)

pyautogui.click(x=716, y=476)

time.sleep(5)
    
    
#Passo 3: Baixar a base de dados
pyautogui.click(x=366, y=307)
time.sleep(1)
pyautogui.click(x=505, y=160)
time.sleep(7)
pyautogui.hotkey("enter")

# %%
#Passo 4: Calcular os indicadores
import pandas as pd

#importar a base de dados
tabela = pd.read_csv(r"C:\Users\yurir\Downloads\Compras.csv", sep=";")
display(tabela)

# calculo dos insicadores 

#total gasto -> somar a coluna valor final
total_gasto = tabela["ValorFinal"].sum()

#qunatidade -> somar a coluna quantidade
quantidade = tabela["Quantidade"].sum()

#preço média -> total gosto/quantidade 
preco_med = total_gasto / quantidade

print(total_gasto)
print(quantidade)
print(preco_med)
# Out:
#       CódigoCompra        Data               Fornecedor  ... Quantidade  ValorUnitário  ValorFinal
# 0            65014  01/12/2023   Fabrica Hashtag Brasil  ...          5         259.00     1295.00
# 1            65014  01/12/2023   Fabrica Hashtag Brasil  ...          1         380.00      380.00
# 2            65016  01/12/2023   Fabrica Doidona Brasil  ...          2         479.00      958.00
# 3            65016  01/12/2023   Fabrica Doidona Brasil  ...          1          18.90       18.90
# 4            65017  01/12/2023  Original Fábrica Brasil  ...          3         159.90      479.70
# ...            ...         ...                      ...  ...        ...            ...         ...
# 4538         69996  26/12/2023        Revenda Argentina  ...          2          10.00       20.00
# 4539         69996  26/12/2023        Revenda Argentina  ...          4         156.40      625.60
# 4540         69996  26/12/2023        Revenda Argentina  ...          1         183.89      183.89
# 4541         69997  26/12/2023   Fabrica Doidona Mexico  ...          1         359.91      359.91
# 4542         69997  26/12/2023   Fabrica Doidona Mexico  ...          2         502.55     1005.10
#
# [4543 rows x 7 columns]
# 7254196.58
# 9715
# 746.7006258363356

# %%
import pyperclip
#Passo 5: Enviar o email para a diretoria/para o chefe

# Entrar no meu email e escrever mensagem
pyautogui.hotkey("ctrl", "t")
pyautogui.write("https://mail.google.com/mail/u/0/#inbox")
pyautogui.press("enter")
time.sleep(4)
pyautogui.press("c")

# Preencher o email
pyautogui.write("pythonimpressionador@gmail.com")
pyautogui.press("tab") #seleciona o email

pyautogui.press("tab") #passa para campo cc
pyperclip.copy("Relatorio de preços")
pyautogui.hotkey("ctrl", "v")

pyautogui.press("tab") #passa para campo de mensagem

texto = f"""
Prezados,

Segue relatório de compras

Total gasto: R${total_gasto:,.2f}
Quantidade de Produtos: {quantidade:}
Preço Médio: R${preco_med:,.2f}

Qualquer dúvida é só falar.
Att
Yuri Ribeiro
"""

pyperclip.copy(texto)
pyautogui.hotkey("ctrl", "v")

# Enviar
pyautogui.hotkey("ctrl", "enter")

# %%
time.sleep(5)
print(pyautogui.position())
# Out:
# Point(x=505, y=160)

# %%
# !pip install pyautogui
# Out:
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.53.tar.gz (59 kB)
#      ---------------------------------------- 59.0/59.0 kB 3.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pymsgbox
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting PyTweening>=1.0.1
#   Downloading pytweening-1.0.7.tar.gz (168 kB)
#      ------------------------------------- 168.2/168.2 kB 10.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyscreeze>=0.1.21
#   Downloading PyScreeze-0.1.28.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting pygetwindow>=0.0.5
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting mouseinfo
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyrect
#   Downloading PyRect-0.2.0.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: pyautogui, pygetwindow, pyscreeze, PyTweening, mouseinfo, pymsgbox, pyperclip, pyrect
#   Building wheel for pyautogui (setup.py): started
#   Building wheel for pyautogui (setup.py): finished with status 'done'
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36621 sha256=19be0952324473d10f92975475110483873305f328a2b24fbd68c126ab8db830
#   Stored in directory: c:\users\yurir\appdata\local\pip\cache\wheels\f3\5a\96\45dbf918cc12979b2068357eb22c87875e2aeedcda080ec286
#   Building wheel for pygetwindow (setup.py): started
#   Building wheel for pygetwindow (setup.py): finished with status 'done'
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11079 sha256=9ecfaffa98ad98674bffee7b6874d1b98f59dd67ae29905526837ca456e04159
#   Stored in directory: c:\users\yurir\appdata\local\pip\cache\wheels\b4\ba\41\c09cef95c23cdfed6af9df7328306fafbf27df2e77b14d25d7
#   Building wheel for pyscreeze (pyproject.toml): started
#   Building wheel for pyscreeze (pyproject.toml): finished with status 'done'
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.28-py3-none-any.whl size=13026 sha256=8c1fc2f4a190d9501af97f51c0ccf0b46a00e5f8bd6dbe2dc3c05bfcd698f9ef
#   Stored in directory: c:\users\yurir\appdata\local\pip\cache\wheels\f7\3c\82\2e45b77cc2efeb7db09eb00bae84c0b3f6d80683c20e98394b
#   Building wheel for PyTweening (setup.py): started
#   Building wheel for PyTweening (setup.py): finished with status 'done'
#   Created wheel for PyTweening: filename=pytweening-1.0.7-py3-none-any.whl size=6214 sha256=bfac166fd9b610f312aee80650909b0984ee443ba89fd5982a7844eb680ff446
#   Stored in directory: c:\users\yurir\appdata\local\pip\cache\wheels\c6\4a\25\8e83858414a3d4f8d69cb04f86501b11160106b05fc9c8063b
#   Building wheel for mouseinfo (setup.py): started
#   Building wheel for mouseinfo (setup.py): finished with status 'done'
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10906 sha256=07e6466b585efafc0da3d9d191a6d89db94c233d551415a6d6233b62e2ea5a6d
#   Stored in directory: c:\users\yurir\appdata\local\pip\cache\wheels\52\e8\77\5f70ba97301c6d825754eea9f12f0ffd00e119fba64a68f4d2
#   Building wheel for pymsgbox (pyproject.toml): started
#   Building wheel for pymsgbox (pyproject.toml): finished with status 'done'
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7417 sha256=78cddbd5beb7b13bd1df203ed6a299584162cbfda0fde11f2055a1a1f8cd60eb
#   Stored in directory: c:\users\yurir\appdata\local\pip\cache\wheels\97\61\22\1a0de2324b204d675c5bfb28b944101eb48dcf1a1fe87bcce7
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=f48d04c964ddd8983553be8012058e2617818017daf5d1a389595846cbdefb24
#   Stored in directory: c:\users\yurir\appdata\local\pip\cache\wheels\3c\77\81\aaa2802e9b0553585f2789c6f2756b50a09a01d2848423bb15
#   Building wheel for pyrect (setup.py): started
#   Building wheel for pyrect (setup.py): finished with status 'done'
#   Created wheel for pyrect: filename=PyRect-0.2.0-py2.py3-none-any.whl size=11205 sha256=5efe76401d14bfe4c38abaa6977052fcc65bb17b1db4c40703092e848e674d0c
#   Stored in directory: c:\users\yurir\appdata\local\pip\cache\wheels\63\0e\55\adb1553ad973caacffc0bd779f74f4749f904da246674a26a1
# Successfully built pyautogui pygetwindow pyscreeze PyTweening mouseinfo pymsgbox pyperclip pyrect
# Installing collected packages: PyTweening, pyscreeze, pyrect, pyperclip, pymsgbox, pygetwindow, mouseinfo, pyautogui
# Successfully installed PyTweening-1.0.7 mouseinfo-0.1.3 pyautogui-0.9.53 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.2.0 pyscreeze-0.1.28
